# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/churn_df.csv")

# %%
df.sample(5)
# Out:
#       Age  Avg Monthly GB Download  Avg Monthly Long Distance Charges  \
# 4193   29                       51                               2.87
# 2971   26                       69                              36.70
# 298    62                       10                              32.12
# 2255   29                       85                              48.49
# 3757   40                       21                              29.92
#
#      Churn Category                               Churn Reason  Churn Score  \
# 4193     Competitor               Competitor made better offer           80
# 2971            NaN                                        NaN           33
# 298      Competitor               Competitor made better offer           74
# 2255            NaN                                        NaN           54
# 3757     Competitor  Competitor offered higher download speeds           77
#
#              City  CLTV        Contract        Country  ... Tenure in Months  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4225 entries, 0 to 4224
# Data columns (total 52 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                4225 non-null   int64
#  1   Avg Monthly GB Download            4225 non-null   int64
#  2   Avg Monthly Long Distance Charges  4225 non-null   float64
#  3   Churn Category                     1121 non-null   str
#  4   Churn Reason                       1121 non-null   str
#  5   Churn Score                        4225 non-null   int64
#  6   City                               4225 non-null   str
#  7   CLTV                               4225 non-null   int64
#  8   Contract                           4225 non-null   str
#  9   Country                            4225 non-null   str
#  10  Customer ID                        4225 non-null   str
#  11  Customer Status                    4225 non-null   str
# ...

# %%
df = df[["CLTV", "Contract", "Dependents", "Multiple Lines", "Offer", "Satisfaction Score", "Tenure in Months", "Total Charges", "Total Revenue", "Churn"]]

# %%
df["Contract"].unique()
# Out:
# <StringArray>
# ['Two Year', 'Month-to-Month', 'One Year']
# Length: 3, dtype: str

# %%
df["Offer"].unique()
# Out:
# <StringArray>
# [nan, 'Offer B', 'Offer E', 'Offer A', 'Offer D', 'Offer C']
# Length: 6, dtype: str

# %%
df["Offer"] = df["Offer"].map({'Offer E':1,'Offer B':1,'Offer A':1,'Offer D':1, 'Offer C':1})
df["Contract"] = df["Contract"].map({'Two Year':24,'Month-to-Month':1,'One Year':12})
df["Offer"]=df["Offer"].replace({np.nan:0})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4225 entries, 0 to 4224
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CLTV                4225 non-null   int64
#  1   Contract            4225 non-null   int64
#  2   Dependents          4225 non-null   int64
#  3   Multiple Lines      4225 non-null   int64
#  4   Offer               4225 non-null   float64
#  5   Satisfaction Score  4225 non-null   int64
#  6   Tenure in Months    4225 non-null   int64
#  7   Total Charges       4225 non-null   float64
#  8   Total Revenue       4225 non-null   float64
#  9   Churn               4225 non-null   int64
# dtypes: float64(3), int64(7)
# memory usage: 330.2 KB

# %%
df.to_csv('../data/cleaned_df.csv', index=False)
